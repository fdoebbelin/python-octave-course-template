# %% [markdown]
# # Einführung in Python und NumPy

# %%
import numpy as np
x = np.linspace(0, 10, 5)
y = np.sin(x)
for i, val in enumerate(y):
    print(f'sin({x[i]:.1f}) = {val:.3f}')
# Out:
# sin(0.0) = 0.000
# sin(2.5) = 0.598
# sin(5.0) = -0.959
# sin(7.5) = 0.938
# sin(10.0) = -0.544
